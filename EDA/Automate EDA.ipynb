# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('Sample hotel data.csv')
df.head()
# Out:
#                          Hotel_Name_City  Review_Overall_Rating  \
# 0                    Bombay Hotel Jaipur                      3
# 1                    Bombay Hotel Jaipur                      1
# 2  Coffea Aroma Resort - Wayanad Meppadi                      2
# 3  Coffea Aroma Resort - Wayanad Meppadi                      3
# 4  Coffea Aroma Resort - Wayanad Meppadi                      3
#
#   date_of_review Month_of_Visit   Review_Type  Rating_Value  Rating_Location  \
# 0      8/26/2014         Aug-14   with family           3.0              4.0
# 1     06-02-2013         Jun-13           NaN           1.0              2.0
# 2     10/20/2014         Oct-14  with friends           2.0              NaN
# 3      9/29/2014         Sep-14  with friends           NaN              4.0
# 4     09-03-2014         Jul-14   as a couple           NaN              NaN
#
#    Rating_Sleep_Quality  Rating_Rooms  Rating_Cleanliness  Rating_Service
# 0                   NaN           NaN                 NaN             3.0
# 1                   NaN           1.0                 1.0             3.0
# 2                   NaN           2.0                 NaN             1.0
# 3                   NaN           NaN                 3.0             3.0
# 4                   3.0           2.0                 NaN             5.0

# %%
# !pip3 install sweetviz
# Out:
# Collecting sweetviz
#   Downloading sweetviz-2.3.1-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (2.2.2)
# Requirement already satisfied: numpy>=1.16.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (2.1.1)
# Requirement already satisfied: matplotlib>=3.1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (3.9.2)
# Requirement already satisfied: tqdm>=4.43.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (4.66.5)
# Requirement already satisfied: scipy>=1.3.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (1.14.1)
# Requirement already satisfied: jinja2>=2.11.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from sweetviz) (3.1.4)
# Collecting importlib-resources>=1.2.0 (from sweetviz)
#   Downloading importlib_resources-6.4.5-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from jinja2>=2.11.1->sweetviz) (2.1.5)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (24.1)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib>=3.1.3->sweetviz) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas!=1.0.0,!=1.0.1,!=1.0.2,>=0.25.3->sweetviz) (2024.1)
# Requirement already satisfied: six>=1.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from python-dateutil>=2.7->matplotlib>=3.1.3->sweetviz) (1.16.0)
# Downloading sweetviz-2.3.1-py3-none-any.whl (15.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 13.5 MB/s eta 0:00:00a 0:00:01
# Downloading importlib_resources-6.4.5-py3-none-any.whl (36 kB)
# Installing collected packages: importlib-resources, sweetviz
# Successfully installed importlib-resources-6.4.5 sweetviz-2.3.1

# %%
import sweetviz as sv
hotelsfeedback_report = sv.analyze(df)
hotelsfeedback_report.show_html('Analyst.html')
# Out:
#                                              |      | [  0%]   00:00 -> (? left)
# Report Analyst.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 942 entries, 0 to 941
# Data columns (total 11 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Hotel_Name_City        942 non-null    object
#  1   Review_Overall_Rating  942 non-null    int64
#  2   date_of_review         942 non-null    object
#  3   Month_of_Visit         936 non-null    object
#  4   Review_Type            870 non-null    object
#  5   Rating_Value           818 non-null    float64
#  6   Rating_Location        799 non-null    float64
#  7   Rating_Sleep_Quality   690 non-null    float64
#  8   Rating_Rooms           797 non-null    float64
#  9   Rating_Cleanliness     816 non-null    float64
#  10  Rating_Service         875 non-null    float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 81.1+ KB

# %%
# !pip3 install dtale
# Out:
# Collecting dtale
#   Downloading dtale-3.16.0-py2.py3-none-any.whl.metadata (16 kB)
# Collecting dash-colorscales (from dtale)
#   Downloading dash_colorscales-0.0.4.tar.gz (62 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting dash-daq (from dtale)
#   Downloading dash_daq-0.5.0.tar.gz (642 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 642.7/642.7 kB 11.5 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting future>=0.14.0 (from dtale)
#   Downloading future-1.0.0-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: missingno in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (0.5.2)
# Requirement already satisfied: pandas in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (2.2.2)
# Collecting squarify (from dtale)
#   Downloading squarify-0.4.4-py3-none-any.whl.metadata (600 bytes)
# Collecting strsimpy (from dtale)
#   Downloading strsimpy-0.2.1-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: six in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (1.16.0)
# Collecting xlrd (from dtale)
#   Downloading xlrd-2.0.1-py2.py3-none-any.whl.metadata (3.4 kB)
# Requirement already satisfied: beautifulsoup4!=4.13.0b2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (4.12.3)
# Requirement already satisfied: certifi in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (2024.8.30)
# Collecting dash-bootstrap-components (from dtale)
#   Downloading dash_bootstrap_components-1.6.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting lz4 (from dtale)
#   Downloading lz4-4.3.3-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.7 kB)
# Requirement already satisfied: cycler in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (0.12.1)
# Collecting dash (from dtale)
#   Downloading dash-2.18.2-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: seaborn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (0.13.2)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting Flask-Compress (from dtale)
#   Downloading Flask_Compress-1.17-py3-none-any.whl.metadata (8.8 kB)
# Requirement already satisfied: scikit-learn in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (1.5.2)
# Collecting statsmodels (from dtale)
#   Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Requirement already satisfied: networkx in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (3.4.1)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (2.1.1)
# Requirement already satisfied: openpyxl!=3.2.0b1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (3.1.5)
# Collecting xarray (from dtale)
#   Downloading xarray-2024.11.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: scipy!=1.12.0rc1,!=1.14.0,!=1.14.0rc1,!=1.14.0rc2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (1.14.1)
# Requirement already satisfied: et-xmlfile in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (2.0.0)
# Collecting plotly (from dtale)
#   Downloading plotly-5.24.1-py3-none-any.whl.metadata (7.3 kB)
# Collecting Flask (from dtale)
#   Downloading flask-3.1.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting itsdangerous (from dtale)
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: requests in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (2.32.3)
# Collecting kaleido (from dtale)
#   Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl.metadata (15 kB)
# Requirement already satisfied: matplotlib in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dtale) (3.9.2)
# Requirement already satisfied: soupsieve>1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from beautifulsoup4!=4.13.0b2->dtale) (2.6)
# Collecting Flask (from dtale)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting werkzeug (from dtale)
#   Downloading werkzeug-3.0.6-py3-none-any.whl.metadata (3.7 kB)
# Collecting dash-html-components==2.0.0 (from dash->dtale)
#   Downloading dash_html_components-2.0.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting dash-core-components==2.0.0 (from dash->dtale)
#   Downloading dash_core_components-2.0.0-py3-none-any.whl.metadata (2.9 kB)
# Collecting dash-table==5.0.0 (from dash->dtale)
#   Downloading dash_table-5.0.0-py3-none-any.whl.metadata (2.4 kB)
# Collecting importlib-metadata (from dash->dtale)
#   Downloading importlib_metadata-8.5.0-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: typing-extensions>=4.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dash->dtale) (4.12.2)
# Collecting retrying (from dash->dtale)
#   Downloading retrying-1.3.4-py3-none-any.whl.metadata (6.9 kB)
# Requirement already satisfied: nest-asyncio in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dash->dtale) (1.6.0)
# Requirement already satisfied: setuptools in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from dash->dtale) (74.1.0)
# Requirement already satisfied: Jinja2>=3.1.2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Flask->dtale) (3.1.4)
# Requirement already satisfied: click>=8.1.3 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from Flask->dtale) (8.1.7)
# Collecting blinker>=1.6.2 (from Flask->dtale)
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting tenacity>=6.2.0 (from plotly->dtale)
#   Downloading tenacity-9.0.0-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: packaging in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from plotly->dtale) (24.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from werkzeug->dtale) (2.1.5)
# Collecting brotli (from Flask-Compress->dtale)
#   Downloading Brotli-1.1.0-cp312-cp312-macosx_10_13_universal2.whl.metadata (5.5 kB)
# Collecting zstandard (from Flask-Compress->dtale)
#   Downloading zstandard-0.23.0-cp312-cp312-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (1.3.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (1.4.7)
# Requirement already satisfied: pillow>=8 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from matplotlib->dtale) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->dtale) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from pandas->dtale) (2024.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->dtale) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->dtale) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from requests->dtale) (2.2.2)
# Collecting joblib>=1.2.0 (from scikit-learn->dtale)
#   Using cached joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages (from scikit-learn->dtale) (3.5.0)
# Collecting patsy>=0.5.6 (from statsmodels->dtale)
#   Downloading patsy-1.0.1-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting zipp>=3.20 (from importlib-metadata->dash->dtale)
#   Downloading zipp-3.21.0-py3-none-any.whl.metadata (3.7 kB)
# Downloading dtale-3.16.0-py2.py3-none-any.whl (14.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.7/14.7 MB 13.6 MB/s eta 0:00:0000:0100:01
# Downloading future-1.0.0-py3-none-any.whl (491 kB)
# Downloading dash-2.18.2-py3-none-any.whl (7.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 14.2 MB/s eta 0:00:00a 0:00:01
# Downloading dash_core_components-2.0.0-py3-none-any.whl (3.8 kB)
# Downloading dash_html_components-2.0.0-py3-none-any.whl (4.1 kB)
# Downloading dash_table-5.0.0-py3-none-any.whl (3.9 kB)
# Downloading flask-3.0.3-py3-none-any.whl (101 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading plotly-5.24.1-py3-none-any.whl (19.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 12.5 MB/s eta 0:00:00a 0:00:01
# Downloading werkzeug-3.0.6-py3-none-any.whl (227 kB)
# Downloading dash_bootstrap_components-1.6.0-py3-none-any.whl (222 kB)
# Downloading Flask_Compress-1.17-py3-none-any.whl (8.7 kB)
# Downloading kaleido-0.2.1-py2.py3-none-macosx_11_0_arm64.whl (85.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.8/85.8 MB 12.6 MB/s eta 0:00:0000:0100:01
# Downloading lz4-4.3.3-cp312-cp312-macosx_11_0_arm64.whl (212 kB)
# Downloading squarify-0.4.4-py3-none-any.whl (4.1 kB)
# Downloading statsmodels-0.14.4-cp312-cp312-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 14.4 MB/s eta 0:00:00a 0:00:01
# Downloading strsimpy-0.2.1-py3-none-any.whl (45 kB)
# Downloading xarray-2024.11.0-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 19.9 MB/s eta 0:00:00
# Downloading xlrd-2.0.1-py2.py3-none-any.whl (96 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Using cached joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Downloading tenacity-9.0.0-py3-none-any.whl (28 kB)
# Downloading Brotli-1.1.0-cp312-cp312-macosx_10_13_universal2.whl (815 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 815.7/815.7 kB 23.2 MB/s eta 0:00:00
# Downloading importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Downloading retrying-1.3.4-py3-none-any.whl (11 kB)
# Downloading zstandard-0.23.0-cp312-cp312-macosx_11_0_arm64.whl (633 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.5/633.5 kB 15.5 MB/s eta 0:00:00
# Downloading zipp-3.21.0-py3-none-any.whl (9.6 kB)
# Building wheels for collected packages: dash-colorscales, dash-daq
#   Building wheel for dash-colorscales (pyproject.toml) ... done
#   Created wheel for dash-colorscales: filename=dash_colorscales-0.0.4-py3-none-any.whl size=62566 sha256=8a01d94d4413ba8a42e28164213bbd73ed9166c60d55a86cabeb85414f4f6e43
#   Stored in directory: /Users/deeppaghdal/Library/Caches/pip/wheels/84/23/44/63e5ef837d475b972c17c0a841473421c954069fdd7ba062ad
#   Building wheel for dash-daq (pyproject.toml) ... done
#   Created wheel for dash-daq: filename=dash_daq-0.5.0-py3-none-any.whl size=669693 sha256=e7baae5b1b1be46d3c21e48c35ce9dd713651f9104be73422542641de4dde9bb
#   Stored in directory: /Users/deeppaghdal/Library/Caches/pip/wheels/40/89/1a/4435006b003f97da22dbcad819d26f957dad9d54a1678876fd
# Successfully built dash-colorscales dash-daq
# Installing collected packages: strsimpy, squarify, kaleido, dash-table, dash-html-components, dash-core-components, dash-colorscales, brotli, zstandard, zipp, xlrd, werkzeug, tenacity, retrying, patsy, lz4, joblib, itsdangerous, future, blinker, plotly, importlib-metadata, Flask, xarray, statsmodels, Flask-Compress, dash, dash-daq, dash-bootstrap-components, dtale
#   Attempting uninstall: joblib
#     Found existing installation: joblib 1.1.1
#     Uninstalling joblib-1.1.1:
#       Successfully uninstalled joblib-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# pandas-profiling 3.2.0 requires joblib~=1.1.0, but you have joblib 1.4.2 which is incompatible.
# Successfully installed Flask-3.0.3 Flask-Compress-1.17 blinker-1.9.0 brotli-1.1.0 dash-2.18.2 dash-bootstrap-components-1.6.0 dash-colorscales-0.0.4 dash-core-components-2.0.0 dash-daq-0.5.0 dash-html-components-2.0.0 dash-table-5.0.0 dtale-3.16.0 future-1.0.0 importlib-metadata-8.5.0 itsdangerous-2.2.0 joblib-1.4.2 kaleido-0.2.1 lz4-4.3.3 patsy-1.0.1 plotly-5.24.1 retrying-1.3.4 squarify-0.4.4 statsmodels-0.14.4 strsimpy-0.2.1 tenacity-9.0.0 werkzeug-3.0.6 xarray-2024.11.0 xlrd-2.0.1 zipp-3.21.0 zstandard-0.23.0

# %%
import seaborn as sns

# %%
import dtale 
dtale.show(df)
# Out:
#         <iframe
#             width="100%"
#             height="475"
#             src="http://Deeps-MacBook-Air-2.local:40000/dtale/iframe/1"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
